# %% [markdown]
# <a href="https://colab.research.google.com/github/sleevetug/Eloise/blob/main/Encode_Disability.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
import json

def get_data():
  url="https://qqlwlo6mlj.execute-api.eu-west-2.amazonaws.com/test/listening_data"
  query_data = {
      "query":"read_responders",
      "returnfields":[],
      "variables":{}
  }
  data = requests.post(url, data=json.dumps(query_data)).json()
  display(data)
  if 'success' in data.keys():
    return pd.json_normalize(data['success'])
  else:
    return None

df = get_data()
display(df)
if df is not None:

    def encode_disability(df, **kwds):

        df["disability"] = df["disability"].str.lower()

        key = kwds['key']

        if df[key] == "no":
          return 1
        else:
          return 0

    df["disability-encoded"] = df.apply(encode_disability, axis=1, key="disability")
    df
# Out:
# {'message': 'Internal server error'}
# None

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://drive.google.com/uc?export=download&id=144dlnCJ7rHs4LllVqXtsg2ABpnN_XucB"
df = pd.read_csv(url)

df = df[['Where are you based?', 'Which age range are you in?', 'How would you describe your gender?', 'Are you living with a disability or a long-term condition? If so how would you describe this?']]

def lowercase():
    df['Are you living with a disability or a long-term condition? If so how would you describe this?'] = df['Are you living with a disability or a long-term condition? If so how would you describe this?'].str.lower()
lowercase()

def encode_disability(df, **kwds):

    key = kwds['key']

    if df[key] == "no":
        return 1
    else:
        return 0

df["disability-encoded"] = df.apply(encode_disability, axis=1, key="Are you living with a disability or a long-term condition? If so how would you describe this?")
df

# def test_disability():

#     print(df['disability-encoded'].value_counts())

# test_disability()
# Out:
#     Where are you based? Which age range are you in?  \
# 0                 Medway                       70-79
# 1                 Medway                       60-69
# 2                 Medway                       60-69
# 3                 Medway                       70-79
# 4                 Medway                       40-49
# ..                   ...                         ...
# 174               Medway                       50-59
# 175               Medway                       60-69
# 176               Medway                       60-69
# 177               Medway                       70-79
# 178               Medway                       70-79
#
#     How would you describe your gender?  \
# 0                                  Male
# 1                                  Male
# 2                                  Male
# 3                                Female
# 4                                Female
# ..                                  ...
# 174                                Male
# 175                                Male
# 176                              Female
# 177                              Female
# 178                              Female
#
#     Are you living with a disability or a long-term condition? If so how would you describe this?  \
# 0                              after affects of cancer
# 1                mental health condition - depression.
# 2                       alcohol dependent, stoma bag.
# 3         copd, mental health condition - depression.
# 4                   yes but not want to give any info.
# ..                                                 ...
# 174                                                 no
# 175                                                 no
# 176                                                 no
# 177                                                 no
# 178                                                 no
#
#      disability-encoded
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ..                  ...
# 174                   1
# 175                   1
# 176                   1
# 177                   1
# 178                   1
#
# [179 rows x 5 columns]
